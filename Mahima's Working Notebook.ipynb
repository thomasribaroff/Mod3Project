# %%
import pandas as pd
import numpy as np
import requests
import json

# %%
resp = requests.get('https://data.police.uk/api/crimes-street/all-crime?lat=52.629729&lng=-1.131592&date=2017-01').json()

# %%
resp
# Out:
# [{'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '52.617939',
#    'street': {'id': 882393, 'name': 'On or near Edward Road'},
#    'longitude': '-1.118129'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 54163768,
#   'location_subtype': '',
#   'month': '2017-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '52.629288',
#    'street': {'id': 883477, 'name': 'On or near Saxon Street'},
#    'longitude': '-1.148041'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 54162781,
#   'location_subtype': '',
#   'month': '2017-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '52.628321',
#    'street': {'id': 883044, 'name': 'On or near Upper Tichborne Street'},
#    'longitude': '-1.116606'},
#   'context': '',
#   'outcome_status': None,
# ...

# %%
response = requests.get('https://data.police.uk/api/crime-categories?date=2011-08').json()

# %%
response
# Out:
# [{'url': 'all-crime', 'name': 'All crime'},
#  {'url': 'anti-social-behaviour', 'name': 'Anti-social behaviour'},
#  {'url': 'bicycle-theft', 'name': 'Bicycle theft'},
#  {'url': 'burglary', 'name': 'Burglary'},
#  {'url': 'criminal-damage-arson', 'name': 'Criminal damage and arson'},
#  {'url': 'drugs', 'name': 'Drugs'},
#  {'url': 'other-theft', 'name': 'Other theft'},
#  {'url': 'possession-of-weapons', 'name': 'Possession of weapons'},
#  {'url': 'public-order', 'name': 'Public order'},
#  {'url': 'robbery', 'name': 'Robbery'},
#  {'url': 'shoplifting', 'name': 'Shoplifting'},
#  {'url': 'theft-from-the-person', 'name': 'Theft from the person'},
#  {'url': 'vehicle-crime', 'name': 'Vehicle crime'},
#  {'url': 'violent-crime', 'name': 'Violence and sexual offences'},
#  {'url': 'other-crime', 'name': 'Other crime'}]

# %%
borough_data = pd.read_excel('neets-borough-region.xls', sheet_name='Annual (16-24) by NUTS3')

# %%
borough_data
# Out:
#    Unnamed: 0                             Unnamed: 1    2010 Unnamed: 3  \
# 0        Code                                Borough    NEET      Total
# 1         NaN                                    NaN     NaN        NaN
# 2       UKI11                      West Inner London   18000     126000
# 3       UKI12                      East Inner London   45000     285000
# 4       UKI21         East & North East Outer London   33000     213000
# 5       UKI22                     South Outer London   16000     126000
# 6       UKI23         West & North West Outer London   30000     227000
# 7         NaN                                    NaN     NaN        NaN
# 8   E13000001                           Inner London   63000     411000
# 9   E13000002                           Outer London   80000     565000
# 10  E12000007                                 London  143000     976000
# 11        NaN                                    NaN     NaN        NaN
# ...

# %%
borough_data.drop(['Unnamed:0', 'Unnamed:3', 'Unnamed:'])
