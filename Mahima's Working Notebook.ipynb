# %%
#Checking for hypothesis 4 - 
# is there a higher proportion of male unemployment (aged 16 and over) 
# in London compared to the rest of UK?

# where unemployment = people out of work, who are actively looking for work and 
# are available to start immediately.

# 1. We have quarterly data from 2009 to 2019 for unemployed males and females
# in London and the rest of UK.

# 2. Using this data, we will check the level of male unemployment
# in four quarters of a particular year(2016) relative to quarters of 
# previous years (2011-'15). The date shown is the month the quarter ends on. 

# 3.H0 = There is no change in male unemployment levels between 2011-'15 and
# 2016
#  H1 = Male Unemployment has increased / decreased between 2011-'15 and 2016


# Importing necessary directories

import pandas as pd
import numpy as np
import requests
import json

# %%
#Importing the .xls file selecting the sheet with gender-related data

gender_data = pd.read_excel('unemployment-equalities-group.xls', sheet_name='Sex')

# %%
gender_data.head()
# Out:
#                   By Sex Unnamed: 1 Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0  16+ unemployment rate        NaN        NaN             NaN        NaN
# 1                    NaN       Male        NaN             NaN        NaN
# 2                    NaN     London        NaN  United Kingdom        NaN
# 3       12 months ending     Number       Rate          Number       Rate
# 4    2009-03-01 00:00:00     164900        7.3         1126300        6.7
#
#   Unnamed: 5 Unnamed: 6      Unnamed: 7 Unnamed: 8
# 0        NaN        NaN             NaN        NaN
# 1     Female        NaN             NaN        NaN
# 2     London        NaN  United Kingdom        NaN
# 3     Number       Rate          Number       Rate
# 4     139000        7.6          797200        5.5

# %%
#Simplifying the nomenclature of columns 

#dropping female data 

df.rename({'By Sex' : 'Date', 
           'Unnamed: 1' : 'No. of unemployed in London',
           'Unnamed: 2' : 'Rate of unemployment in London',
           'Unnamed: 3' : 'No. of unemployed in UK', 
           'Unnamed: 4' : 'Rate of unemployment in UK'}, axis = 1, inplace = True)

df.iloc[:, [0,1,2,3,4]].head()
# Out:
#                   Date No. of unemployed in London  \
# 4  2009-03-01 00:00:00                      164900
# 5  2009-06-01 00:00:00                      182100
# 6  2009-09-01 00:00:00                      186100
# 7  2009-12-01 00:00:00                      204700
# 8  2010-03-01 00:00:00                      210100
#
#   Rate of unemployment in London No. of unemployed in UK  \
# 4                            7.3                 1126300
# 5                            8.1                 1261800
# 6                            8.2                 1377900
# 7                              9                 1441600
# 8                            9.2                 1490300
#
#   Rate of unemployment in UK
# 4                        6.7
# 5                        7.5
# 6                        8.2
# 7                        8.5
# 8                        8.8

# %%
#Checking statistics 

df['No. of unemployed in London'].mean()
# Out:
# 189580.0

# %%
df['No. of unemployed in UK'].mean()
# Out:
# 1339580.0

# %%
df['No. of unemployed in London'].median()
# Out:
# 186100.0

# %%
df['No. of unemployed in UK'].median()
# Out:
# 1377900.0

# %%
df['Rate of unemployment in London'].median()
# Out:
# 8.2

# %%
df['Rate of unemployment in UK'].mean()
# Out:
# 7.94

# %%
df['No. of unemployed in London'].std()
# Out:
# 18212.962416916147

# %%
crime_df = pd.read_csv('/Users/mahimakaushiva/Desktop/Mod3Project/London Crime Data 2011 to 2014/2010-12-metropolitan-street.csv')
crime_df.head()
# Out:
#    Crime ID    Month                  Reported by  \
# 0       NaN  2010-12  Metropolitan Police Service
# 1       NaN  2010-12  Metropolitan Police Service
# 2       NaN  2010-12  Metropolitan Police Service
# 3       NaN  2010-12  Metropolitan Police Service
# 4       NaN  2010-12  Metropolitan Police Service
#
#                   Falls within  Longitude   Latitude  \
# 0  Metropolitan Police Service   0.145949  51.593914
# 1  Metropolitan Police Service   0.140192  51.582311
# 2  Metropolitan Police Service   0.134947  51.588063
# 3  Metropolitan Police Service   0.134947  51.588063
# 4  Metropolitan Police Service   0.134947  51.588063
#
#                       Location  LSOA code                  LSOA name  \
# 0  On or near Providence Place  E01000027  Barking and Dagenham 001A
# 1       On or near Hatch Grove  E01000027  Barking and Dagenham 001A
# 2        On or near Mead Grove  E01000027  Barking and Dagenham 001A
# ...

# %%
crime_df.isna().sum()
# Out:
# Crime ID                 92442
# Month                        0
# Reported by                  0
# Falls within                 0
# Longitude                    0
# Latitude                     0
# Location                     0
# LSOA code                    0
# LSOA name                    0
# Crime type                   0
# Last outcome category    92442
# Context                  92442
# dtype: int64

# %%
crime_df.drop(['Reported by', 'Falls within', 'Longitude', 
               'Latitude', 'Location', 'LSOA code'], axis = 1, inplace = True) # LSOA - lower layer super output area

# %%
crime_df.head()
# Out:
#      Month                  LSOA name             Crime type
# 0  2010-12  Barking and Dagenham 001A  Anti-social behaviour
# 1  2010-12  Barking and Dagenham 001A  Anti-social behaviour
# 2  2010-12  Barking and Dagenham 001A  Anti-social behaviour
# 3  2010-12  Barking and Dagenham 001A  Anti-social behaviour
# 4  2010-12  Barking and Dagenham 001A  Anti-social behaviour

# %%
crime_df.sort_values(by = ['Crime type', 'LSOA name'])
# Out:
#          Month                  LSOA name             Crime type
# 0      2010-12  Barking and Dagenham 001A  Anti-social behaviour
# 1      2010-12  Barking and Dagenham 001A  Anti-social behaviour
# 2      2010-12  Barking and Dagenham 001A  Anti-social behaviour
# 3      2010-12  Barking and Dagenham 001A  Anti-social behaviour
# 4      2010-12  Barking and Dagenham 001A  Anti-social behaviour
# ...        ...                        ...                    ...
# 92422  2010-12           Westminster 024C          Violent crime
# 92427  2010-12           Westminster 024D          Violent crime
# 92434  2010-12           Westminster 024F          Violent crime
# 92435  2010-12           Westminster 024F          Violent crime
# 92436  2010-12           Westminster 024F          Violent crime
#
# [92442 rows x 3 columns]

# %%
for i in 'Crime type':
    if i is 'Violent crime':
        print(i)
    else:
        print ('stop')
# Out:
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
