# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#importing the csv file containing data on street crimes for Dec 2010 
# across all boroughs in England and Wales
years = ['2011','2012','2013','2014']
months = ['01','02','03','04','05','06','07','08','09','10','11','12']
boroughs = ['Barking and Dagenham',
 'Barnet',
 'Bexley',
 'Brent',
 'Bromley',
 'Camden',
 'City of London',
 'Croydon',
 'Ealing',
 'Elmbridge',
 'Enfield',
 'Epping Forest',
 'Epsom and Ewell',
 'Greenwich',
 'Hackney',
 'Hammersmith and Fulham',
 'Haringey',
 'Harrow',
 'Havering',
 'Hertsmere',
 'Hillingdon',
 'Hounslow',
 'Islington',
 'Kensington and Chelsea',
 'Kingston upon Thames',
 'Lambeth',
 'Lewisham',
 'Merton',
 'Newham',
 'Redbridge',
 'Reigate and Banstead',
 'Richmond upon Thames',
 'Sevenoaks',
 'Slough',
 'Southwark',
 'Spelthorne',
 'Sutton',
 'Tandridge',
 'Three Rivers',
 'Thurrock',
 'Tower Hamlets',
 'Waltham Forest',
 'Wandsworth',
 'Westminster']
#years = ['2011']
#months = ['01']
burglar_df = pd.DataFrame()
for year in years:
    for month in months:
        df=pd.DataFrame()
        filename = f'/Users/mahimakaushiva/Desktop/Mod3Project/London Crime Data 2011 to 2014/{year}-{month}-metropolitan-street.csv'
        df = pd.read_csv(filename)
        df['Borough'] = df['LSOA name'].str[:-5]
        df['Location'] = df["Location"].str[11:]
        df=df.drop(columns=["Crime ID","Month","Reported by","Falls within","LSOA name","Last outcome category","Context"])
        for borough in boroughs:
            subset_df = df[(df["Crime type"]=="Burglary")&(df["Borough"]==borough)]
            burglar_df.loc[f'{year}-{month}',borough] = len(subset_df["Borough"])
burglar_df
# Out:
#          Barking and Dagenham  Barnet  Bexley  Brent  Bromley  Camden  \
# 2011-01                 213.0   486.0   188.0  355.0    316.0   298.0
# 2011-02                 175.0   403.0   129.0  302.0    235.0   273.0
# 2011-03                 217.0   408.0   135.0  334.0    237.0   322.0
# 2011-04                 203.0   414.0   108.0  284.0    239.0   295.0
# 2011-05                 192.0   435.0   138.0  324.0    257.0   344.0
# 2011-06                 158.0   411.0   106.0  280.0    214.0   301.0
# 2011-07                 173.0   380.0   109.0  306.0    210.0   243.0
# 2011-08                 195.0   355.0   127.0  231.0    294.0   293.0
# 2011-09                 161.0   305.0   117.0  275.0    252.0   264.0
# 2011-10                 199.0   390.0    81.0  344.0    277.0   210.0
# 2011-11                 225.0   433.0   129.0  393.0    289.0   248.0
# 2011-12                 234.0   439.0   134.0  395.0    361.0   304.0
# ...

# %%
#checking for NaN and Null values 

df.isna().sum()
# Out:
# Crime ID                 19588
# Month                        0
# Reported by                  0
# Falls within                 0
# Longitude                  810
# Latitude                   810
# Location                     0
# LSOA code                  810
# LSOA name                  810
# Crime type                   0
# Last outcome category    19588
# Context                  75196
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Crime ID                 19588
# Month                        0
# Reported by                  0
# Falls within                 0
# Longitude                  810
# Latitude                   810
# Location                     0
# LSOA code                  810
# LSOA name                  810
# Crime type                   0
# Last outcome category    19588
# Context                  75196
# dtype: int64

# %%
#dropping columns with atleast 1 null value 

df.dropna(axis = 'columns', inplace=True)
df
# Out:
#                           Location                  LSOA name  \
# 0      On or near Providence Place  Barking and Dagenham 001A
# 1           On or near Hatch Grove  Barking and Dagenham 001A
# 2            On or near Mead Grove  Barking and Dagenham 001A
# 3            On or near Mead Grove  Barking and Dagenham 001A
# 4            On or near Mead Grove  Barking and Dagenham 001A
# ...                            ...                        ...
# 92437      On or near Lupus Street           Westminster 024F
# 92438  On or near Thorndike Street           Westminster 024F
# 92439    On or near Garden Terrace           Westminster 024F
# 92440    On or near Garden Terrace           Westminster 024F
# 92441      On or near Lupus Street           Westminster 024F
#
#                   Crime type
# 0      Anti-social behaviour
# 1      Anti-social behaviour
# 2      Anti-social behaviour
# 3      Anti-social behaviour
# 4      Anti-social behaviour
# ...                      ...
# ...

# %%
#importing api to check different categories of street crime in 
# England and Wales

reply = requests.get (f'https://data.police.uk/api/crime-categories?date=2011-08').json()
reply
# Out:
# [{'url': 'all-crime', 'name': 'All crime'},
#  {'url': 'anti-social-behaviour', 'name': 'Anti-social behaviour'},
#  {'url': 'bicycle-theft', 'name': 'Bicycle theft'},
#  {'url': 'burglary', 'name': 'Burglary'},
#  {'url': 'criminal-damage-arson', 'name': 'Criminal damage and arson'},
#  {'url': 'drugs', 'name': 'Drugs'},
#  {'url': 'other-theft', 'name': 'Other theft'},
#  {'url': 'possession-of-weapons', 'name': 'Possession of weapons'},
#  {'url': 'public-order', 'name': 'Public order'},
#  {'url': 'robbery', 'name': 'Robbery'},
#  {'url': 'shoplifting', 'name': 'Shoplifting'},
#  {'url': 'theft-from-the-person', 'name': 'Theft from the person'},
#  {'url': 'vehicle-crime', 'name': 'Vehicle crime'},
#  {'url': 'violent-crime', 'name': 'Violence and sexual offences'},
#  {'url': 'other-crime', 'name': 'Other crime'}]

# %%
#checking for incidence of burglary across all boroughs in this time period

is_Burglary = df['Crime type'] == 'Burglary'
print(is_Burglary)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 92437    False
# 92438    False
# 92439    False
# 92440    False
# 92441    False
# Name: Crime type, Length: 92442, dtype: bool

# %%
df_Burglary = df[is_Burglary]
print(is_Burglary.shape)
# Out:
# (92442,)

# %%
def vcp(borough = 'City of London', year='2010', month='12',):
    
    df['LSOA name'].fillna('No location', inplace = True)
            
return len(data.loc[(data['LSOA name'].str.contains("City of London")) & \
                     ((data['Crime type'] == "Violent crime")|(data['Crime type'] == "Violence and sexual offences"))])
       len(data.loc[(data['LSOA name'].str.contains("City of London"))])
# Out:
#   File "<ipython-input-109-bdd4243f4e0d>", line 7
#     len(data.loc[(data['LSOA name'].str.contains("City of London"))])
#     ^
# IndentationError: unexpected indent
