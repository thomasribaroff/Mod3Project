# %%
#We are evaluating crime levels in the boroughs of Greater London between 2011 and 2014. The first step is to look 
#at data for a single month within the time period and conduct EDA. 

#Thereafter we will build possible hypotheses such as has crime gone up in a certain time period or has a specific
#crime has increased across boroughs or how do two boroughs compare for the same kind of crime

#We begin by importing necessary directories 

import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#importing the csv file containing data on street crimes for Dec 2010 across all boroughs in Greater England
#dropping unnecessary columns

df = pd.read_csv('/Users/mahimakaushiva/Desktop/Mod3Project/London Crime Data 2011 to 2014/2011-01-metropolitan-street.csv')
df = df.drop(columns=['Crime ID', 'Reported by', 'Falls within', 'LSOA code', 'Last outcome category', 'Context'])
df
# Out:
#          Month  Longitude   Latitude                       Location  \
# 0      2011-01   0.134947  51.588063          On or near Mead Grove
# 1      2011-01   0.140619  51.583427          On or near Rams Grove
# 2      2011-01   0.134947  51.588063          On or near Mead Grove
# 3      2011-01   0.134947  51.588063          On or near Mead Grove
# 4      2011-01   0.134947  51.588063          On or near Mead Grove
# ...        ...        ...        ...                            ...
# 99094  2011-01  -0.134817  51.490740    On or near Thorndike Street
# 99095  2011-01  -0.134491  51.488846        On or near Lupus Street
# 99096  2011-01  -0.134555  51.490466      On or near Garden Terrace
# 99097  2011-01  -0.135419  51.489041  On or near St George'S Square
# 99098  2011-01  -0.134491  51.488846        On or near Lupus Street
#
#                        LSOA name             Crime type
# 0      Barking and Dagenham 001A  Anti-social behaviour
# 1      Barking and Dagenham 001A  Anti-social behaviour
# 2      Barking and Dagenham 001A  Anti-social behaviour
# 3      Barking and Dagenham 001A  Anti-social behaviour
# 4      Barking and Dagenham 001A  Anti-social behaviour
# ...                          ...                    ...
# 99094           Westminster 024F          Violent crime
# 99095           Westminster 024F          Violent crime
# 99096           Westminster 024F            Other crime
# 99097           Westminster 024F            Other crime
# 99098           Westminster 024F            Other crime
#
# [99099 rows x 6 columns]

# %%
#Since LSOA name contains both the name of the borough and the code, it is difficult to identify by borough alone
#Hence we separate the two 
#We also change location from on or near to just the name of the street for ease of use 

df['Borough'] = df['LSOA name'].str[:-5]
df['Location'] =df['Location'].str[11:]
df = df.drop(columns=['LSOA name'])
df
# Out:
#          Month  Longitude   Latitude            Location  \
# 0      2011-01   0.134947  51.588063          Mead Grove
# 1      2011-01   0.140619  51.583427          Rams Grove
# 2      2011-01   0.134947  51.588063          Mead Grove
# 3      2011-01   0.134947  51.588063          Mead Grove
# 4      2011-01   0.134947  51.588063          Mead Grove
# ...        ...        ...        ...                 ...
# 99094  2011-01  -0.134817  51.490740    Thorndike Street
# 99095  2011-01  -0.134491  51.488846        Lupus Street
# 99096  2011-01  -0.134555  51.490466      Garden Terrace
# 99097  2011-01  -0.135419  51.489041  St George'S Square
# 99098  2011-01  -0.134491  51.488846        Lupus Street
#
#                   Crime type               Borough
# 0      Anti-social behaviour  Barking and Dagenham
# 1      Anti-social behaviour  Barking and Dagenham
# 2      Anti-social behaviour  Barking and Dagenham
# 3      Anti-social behaviour  Barking and Dagenham
# 4      Anti-social behaviour  Barking and Dagenham
# ...                      ...                   ...
# 99094          Violent crime           Westminster
# 99095          Violent crime           Westminster
# 99096            Other crime           Westminster
# 99097            Other crime           Westminster
# 99098            Other crime           Westminster
#
# [99099 rows x 6 columns]

# %%
#Classifying incidence of crime as per boroughs

df.groupby(['Borough','Crime type']).count()
# Out:
#                                             Month  Longitude  Latitude  \
# Borough              Crime type
# Barking and Dagenham Anti-social behaviour    801        801       801
#                      Burglary                 213        213       213
#                      Other crime              653        653       653
#                      Robbery                   80         80        80
#                      Vehicle crime            244        244       244
# ...                                           ...        ...       ...
# Westminster          Burglary                 328        328       328
#                      Other crime             3793       3793      3793
#                      Robbery                  199        199       199
#                      Vehicle crime            281        281       281
#                      Violent crime            693        693       693
#
#                                             Location
# Borough              Crime type
# Barking and Dagenham Anti-social behaviour       801
#                      Burglary                    213
#                      Other crime                 653
#                      Robbery                      80
#                      Vehicle crime               244
# ...                                              ...
# Westminster          Burglary                    328
#                      Other crime                3793
#                      Robbery                     199
#                      Vehicle crime               281
#                      Violent crime               693
#
# [215 rows x 4 columns]

# %%
#checking for crime type across boroughs

df.groupby(['Crime type', 'Borough']).count()
# Out:
#                                             Month  Longitude  Latitude  \
# Crime type            Borough
# Anti-social behaviour Barking and Dagenham    801        801       801
#                       Barnet                 1115       1115      1115
#                       Bexley                  648        648       648
#                       Brent                  1156       1156      1156
#                       Bromley                1017       1017      1017
# ...                                           ...        ...       ...
# Violent crime         Sutton                  179        179       179
#                       Tower Hamlets           468        468       468
#                       Waltham Forest          450        450       450
#                       Wandsworth              298        298       298
#                       Westminster             693        693       693
#
#                                             Location
# Crime type            Borough
# Anti-social behaviour Barking and Dagenham       801
#                       Barnet                    1115
#                       Bexley                     648
#                       Brent                     1156
#                       Bromley                   1017
# ...                                              ...
# Violent crime         Sutton                     179
#                       Tower Hamlets              468
#                       Waltham Forest             450
#                       Wandsworth                 298
#                       Westminster                693
#
# [215 rows x 4 columns]

# %%
#checking for the list of unique boroughs

boroughs = set(df['Borough'])
boroughs
# Out:
# {'Barking and Dagenham',
#  'Barnet',
#  'Bexley',
#  'Brent',
#  'Bromley',
#  'Camden',
#  'City of London',
#  'Croydon',
#  'Ealing',
#  'Elmbridge',
#  'Enfield',
#  'Epping Forest',
#  'Epsom and Ewell',
#  'Greenwich',
#  'Hackney',
#  'Hammersmith and Fulham',
#  'Haringey',
#  'Harrow',
#  'Havering',
#  'Hertsmere',
#  'Hillingdon',
#  'Hounslow',
#  'Islington',
#  'Kensington and Chelsea',
#  'Kingston upon Thames',
#  'Lambeth',
#  'Lewisham',
#  'Merton',
#  'Newham',
#  'Redbridge',
#  'Reigate and Banstead',
#  'Richmond upon Thames',
#  'Sevenoaks',
#  'Slough',
#  'Southwark',
#  'Spelthorne',
#  'Sutton',
#  'Tandridge',
#  'Three Rivers',
#  'Thurrock',
#  'Tower Hamlets',
#  'Waltham Forest',
#  'Wandsworth',
#  'Westminster'}

# %%
#In order to build a hypothesis to view data across different files, we create a function that can loop over the time
# period 2011-2014 and repeat the functions we performed in the EDA above to run the code for this new dataframe

years = ['2011']
months = ['01']

for x in years:
    for y in months:
        filename = f'/Users/mahimakaushiva/Desktop/Mod3Project/London Crime Data 2011 to 2014/{x}-{y}-metropolitan-street.csv'
        df = pd.read_csv(filename)
df
# Out:
#        Crime ID    Month                  Reported by  \
# 0           NaN  2011-01  Metropolitan Police Service
# 1           NaN  2011-01  Metropolitan Police Service
# 2           NaN  2011-01  Metropolitan Police Service
# 3           NaN  2011-01  Metropolitan Police Service
# 4           NaN  2011-01  Metropolitan Police Service
# ...         ...      ...                          ...
# 99094       NaN  2011-01  Metropolitan Police Service
# 99095       NaN  2011-01  Metropolitan Police Service
# 99096       NaN  2011-01  Metropolitan Police Service
# 99097       NaN  2011-01  Metropolitan Police Service
# 99098       NaN  2011-01  Metropolitan Police Service
#
#                       Falls within  Longitude   Latitude  \
# 0      Metropolitan Police Service   0.134947  51.588063
# 1      Metropolitan Police Service   0.140619  51.583427
# 2      Metropolitan Police Service   0.134947  51.588063
# 3      Metropolitan Police Service   0.134947  51.588063
# 4      Metropolitan Police Service   0.134947  51.588063
# ...                            ...        ...        ...
# 99094  Metropolitan Police Service  -0.134817  51.490740
# 99095  Metropolitan Police Service  -0.134491  51.488846
# 99096  Metropolitan Police Service  -0.134555  51.490466
# 99097  Metropolitan Police Service  -0.135419  51.489041
# 99098  Metropolitan Police Service  -0.134491  51.488846
#
#                             Location  LSOA code                  LSOA name  \
# 0              On or near Mead Grove  E01000027  Barking and Dagenham 001A
# 1              On or near Rams Grove  E01000027  Barking and Dagenham 001A
# 2              On or near Mead Grove  E01000027  Barking and Dagenham 001A
# 3              On or near Mead Grove  E01000027  Barking and Dagenham 001A
# 4              On or near Mead Grove  E01000027  Barking and Dagenham 001A
# ...                              ...        ...                        ...
# 99094    On or near Thorndike Street  E01004741           Westminster 024F
# 99095        On or near Lupus Street  E01004741           Westminster 024F
# 99096      On or near Garden Terrace  E01004741           Westminster 024F
# 99097  On or near St George'S Square  E01004741           Westminster 024F
# 99098        On or near Lupus Street  E01004741           Westminster 024F
#
#                   Crime type  Last outcome category  Context
# 0      Anti-social behaviour                    NaN      NaN
# 1      Anti-social behaviour                    NaN      NaN
# 2      Anti-social behaviour                    NaN      NaN
# 3      Anti-social behaviour                    NaN      NaN
# 4      Anti-social behaviour                    NaN      NaN
# ...                      ...                    ...      ...
# 99094          Violent crime                    NaN      NaN
# 99095          Violent crime                    NaN      NaN
# 99096            Other crime                    NaN      NaN
# 99097            Other crime                    NaN      NaN
# 99098            Other crime                    NaN      NaN
#
# [99099 rows x 12 columns]

# %%
df = df.drop(columns=['Crime ID', 'Reported by', 'Falls within', 'LSOA code', 'Last outcome category', 'Context'])
df
# Out:
#          Month  Longitude   Latitude                       Location  \
# 0      2011-01   0.134947  51.588063          On or near Mead Grove
# 1      2011-01   0.140619  51.583427          On or near Rams Grove
# 2      2011-01   0.134947  51.588063          On or near Mead Grove
# 3      2011-01   0.134947  51.588063          On or near Mead Grove
# 4      2011-01   0.134947  51.588063          On or near Mead Grove
# ...        ...        ...        ...                            ...
# 99094  2011-01  -0.134817  51.490740    On or near Thorndike Street
# 99095  2011-01  -0.134491  51.488846        On or near Lupus Street
# 99096  2011-01  -0.134555  51.490466      On or near Garden Terrace
# 99097  2011-01  -0.135419  51.489041  On or near St George'S Square
# 99098  2011-01  -0.134491  51.488846        On or near Lupus Street
#
#                        LSOA name             Crime type
# 0      Barking and Dagenham 001A  Anti-social behaviour
# 1      Barking and Dagenham 001A  Anti-social behaviour
# 2      Barking and Dagenham 001A  Anti-social behaviour
# 3      Barking and Dagenham 001A  Anti-social behaviour
# 4      Barking and Dagenham 001A  Anti-social behaviour
# ...                          ...                    ...
# 99094           Westminster 024F          Violent crime
# 99095           Westminster 024F          Violent crime
# 99096           Westminster 024F            Other crime
# 99097           Westminster 024F            Other crime
# 99098           Westminster 024F            Other crime
#
# [99099 rows x 6 columns]

# %%
df['Borough'] = df['LSOA name'].str[:-5]
df['Location'] =df['Location'].str[11:]
df = df.drop(columns=['LSOA name'])
df
# Out:
#          Month  Longitude   Latitude            Location  \
# 0      2011-01   0.134947  51.588063          Mead Grove
# 1      2011-01   0.140619  51.583427          Rams Grove
# 2      2011-01   0.134947  51.588063          Mead Grove
# 3      2011-01   0.134947  51.588063          Mead Grove
# 4      2011-01   0.134947  51.588063          Mead Grove
# ...        ...        ...        ...                 ...
# 99094  2011-01  -0.134817  51.490740    Thorndike Street
# 99095  2011-01  -0.134491  51.488846        Lupus Street
# 99096  2011-01  -0.134555  51.490466      Garden Terrace
# 99097  2011-01  -0.135419  51.489041  St George'S Square
# 99098  2011-01  -0.134491  51.488846        Lupus Street
#
#                   Crime type               Borough
# 0      Anti-social behaviour  Barking and Dagenham
# 1      Anti-social behaviour  Barking and Dagenham
# 2      Anti-social behaviour  Barking and Dagenham
# 3      Anti-social behaviour  Barking and Dagenham
# 4      Anti-social behaviour  Barking and Dagenham
# ...                      ...                   ...
# 99094          Violent crime           Westminster
# 99095          Violent crime           Westminster
# 99096            Other crime           Westminster
# 99097            Other crime           Westminster
# 99098            Other crime           Westminster
#
# [99099 rows x 6 columns]

# %%
df.groupby(['Borough','Crime type']).count()
# Out:
#                                             Month  Longitude  Latitude  \
# Borough              Crime type
# Barking and Dagenham Anti-social behaviour    801        801       801
#                      Burglary                 213        213       213
#                      Other crime              653        653       653
#                      Robbery                   80         80        80
#                      Vehicle crime            244        244       244
# ...                                           ...        ...       ...
# Westminster          Burglary                 328        328       328
#                      Other crime             3793       3793      3793
#                      Robbery                  199        199       199
#                      Vehicle crime            281        281       281
#                      Violent crime            693        693       693
#
#                                             Location
# Borough              Crime type
# Barking and Dagenham Anti-social behaviour       801
#                      Burglary                    213
#                      Other crime                 653
#                      Robbery                      80
#                      Vehicle crime               244
# ...                                              ...
# Westminster          Burglary                    328
#                      Other crime                3793
#                      Robbery                     199
#                      Vehicle crime               281
#                      Violent crime               693
#
# [215 rows x 4 columns]

# %%
df.groupby(['Crime type', 'Borough']).count()
# Out:
#                                             Month  Longitude  Latitude  \
# Crime type            Borough
# Anti-social behaviour Barking and Dagenham    801        801       801
#                       Barnet                 1115       1115      1115
#                       Bexley                  648        648       648
#                       Brent                  1156       1156      1156
#                       Bromley                1017       1017      1017
# ...                                           ...        ...       ...
# Violent crime         Sutton                  179        179       179
#                       Tower Hamlets           468        468       468
#                       Waltham Forest          450        450       450
#                       Wandsworth              298        298       298
#                       Westminster             693        693       693
#
#                                             Location
# Crime type            Borough
# Anti-social behaviour Barking and Dagenham       801
#                       Barnet                    1115
#                       Bexley                     648
#                       Brent                     1156
#                       Bromley                   1017
# ...                                              ...
# Violent crime         Sutton                     179
#                       Tower Hamlets              468
#                       Waltham Forest             450
#                       Wandsworth                 298
#                       Westminster                693
#
# [215 rows x 4 columns]

# %%
#Hypothesis 1: Burglary has increased in Westminster between Jan 2011 and Jan 2012

burglary_df = df[(df['Borough'] == 'Westminster') & ( df['Crime type'] == 'Burglary')]


burglary_df = burglary_df.drop(columns=['Longitude', 'Latitude', 'Location'])
burglary_df
# Out:
#          Month Crime type      Borough
# 92058  2011-01   Burglary  Westminster
# 92059  2011-01   Burglary  Westminster
# 92080  2011-01   Burglary  Westminster
# 92081  2011-01   Burglary  Westminster
# 92082  2011-01   Burglary  Westminster
# ...        ...        ...          ...
# 98676  2011-01   Burglary  Westminster
# 98714  2011-01   Burglary  Westminster
# 98719  2011-01   Burglary  Westminster
# 98731  2011-01   Burglary  Westminster
# 98756  2011-01   Burglary  Westminster
#
# [328 rows x 3 columns]

# %%
#Hypothesis 2: Vehicle crime across boroughs is the same throughout 2011

vehicle_df = df[df['Crime type'] == 'Vehicle crime']
vehicle_df = vehicle_df.drop(columns=['Longitude', 'Latitude', 'Location'])
vehicle_df
# Out:
#          Month     Crime type               Borough
# 25     2011-01  Vehicle crime  Barking and Dagenham
# 26     2011-01  Vehicle crime  Barking and Dagenham
# 27     2011-01  Vehicle crime  Barking and Dagenham
# 42     2011-01  Vehicle crime  Barking and Dagenham
# 43     2011-01  Vehicle crime  Barking and Dagenham
# ...        ...            ...                   ...
# 98793  2011-01  Vehicle crime           Westminster
# 98827  2011-01  Vehicle crime           Westminster
# 99029  2011-01  Vehicle crime           Westminster
# 99079  2011-01  Vehicle crime           Westminster
# 99090  2011-01  Vehicle crime           Westminster
#
# [8158 rows x 3 columns]
